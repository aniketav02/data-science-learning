# %% [markdown]
# ## how to create variables
# - strig,float,interger,boolien
# - tuple,list,list
# - type
# - print()

# %%
name="Aniket"
city="Kolhapur"
line="It's nice day."

# %%
print(name)
print(city)
print(line)
# Out:
# Aniket
# Kolhapur
# It's nice day.

# %%
age=18 #int
name="Aniket" #string
sunny=True #boolean
rain=False #boolean
distance=10.5 #float

# %% [markdown]
# Exercise 1: Create Variables
#
# Create variables for:
#
# - Your name (string)
# - Your age (integer)
# - Your height in feet (float)
# - Whether you like Python (boolean)

# %%
name = "Aniket"
age = 22
height = 5.7
likes_python = True

# %%
print(name)
print(age)
print(height)
print(likes_python)
# Out:
# Aniket
# 22
# 5.7
# True

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
print(type(age))
# Out:
# <class 'int'>

# %%
print(type(height))
# Out:
# <class 'float'>

# %%
print(type(likes_python))
# Out:
# <class 'bool'>

# %% [markdown]
# - Exercise 2: Student Information
#
# - Create variables for:
#
# - Student name
# - Roll number
# - Percentage
# - Passed or not

# %%
name = "Aniket"
roll_number = 2
percentage = 90.00
result = "Passed"

# %%
print(name)
print(roll_number)
print(percentage)
print(result)
# Out:
# Aniket
# 2
# 90.0
# Passed

# %%
print(type(name))
print(type(roll_number))
print(type(percentage))
print(type(result))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %% [markdown]
# - Exercise : Tuple and List
#
# - A tuple of 3 fruits
# - A list of 5 subjects

# %%
fruits = ["apple","banana","cherry"]
subjects = ("maths","science","english","history","geography")

# %%
print(fruits)
# Out:
# ['apple', 'banana', 'cherry']

# %%
print(subjects)
# Out:
# ('maths', 'science', 'english', 'history', 'geography')
