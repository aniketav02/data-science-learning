# %%
x = 10
y = 10

print("x location is->", id(x))
print("y location is->", id(y))
print(x is y)

# %%
x = "Aniket"
y = "Saurabh"

print("x location is->", id(x))
print("y location is->", id(y))

# %%
print(x is y)

# %%
age = int(input("Enter the age of person: "))

if age >=18:
    print("You are applicable for voting...!!")
else:
    print("You are not applicable...!!")

# %%
# write the condition take the marks from user and check the student pass or fail

marks = int(input("Enter Your marks: "))

if marks >=35:
    print("Pass")
else:
    print("Fail")

# %%
# take a username and password from user and print login successfully or not valid
correct_username="Admin"
correct_password= Pass


username = str(input())
password = str(input())

if username == correct_username and correct_username:
    print("Login Successfully")
else:
    print("Not Valid")

# %%
user ='Aniket'
password= 1234

u = input("Enter the username: ")
p = input("Enter the password: ")

if u == user and p == password:
    print("Login Successfully...!!")
else:
    print("Invalid login")

# %%
user ='Aniket'
password= 1234

u = input("Enter the username: ")
p = input("Enter the password: ")

if u == user and p == password:
    print("Login Successfully...!!")
elif  u != user and p == password:
    print("Enter correct User..!!")
elif  u == user and p != password:
    print("Enter correct Password..!!")
else:
    print("Invalid login")

# %%
print("*****CACULATOR*****")

a = int(input("Enter First number: "))
b = int(input("Enter second number: "))

op =input("Enter the operator(+,-,*,/): ")

if op =="+":
    print("Addition  is: ", a+b)
elif op =="-":
    print("Subtraction is: ",a-b)
elif op == "*":
    print("Multiplication is : ",a*b)
elif op == "/":
    print("DIvision is :  ",a/b)
else:
    print("Enter valid opertor...!!")
# Out:
# *****CACULATOR*****
# Addition  is:  20
