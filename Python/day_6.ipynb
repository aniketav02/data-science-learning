# %% [markdown]
# # Tuple

# %%
first_tuple = (1,2,3,4,5)
first_tuple
type(first_tuple)
# Out:
# tuple

# %%
shop=["apple","banana","orange"]
type(shop)
# Out:
# list

# %%
# create tuple

# %%
a =[1,2,3,4,5,6]
b= tuple(a)
b
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# tupel with mixed data types
person = ("Aniket", 21, "Male", 5.9)
print("Person information: ", person)
# Out:
# Person information:  ('Aniket', 21, 'Male', 5.9)

# %%
fruits = ("apple", "banana", "cherry")
print('I like to eat: ',fruits)
# Out:
# I like to eat:  ('apple', 'banana', 'cherry')

# %%
cites =("New York", "London", "Tokyo")
print("I want to visit: ",cites)
# Out:
# I want to visit:  ('New York', 'London', 'Tokyo')

# %% [markdown]
# # Methods
# - count
# - index

# %%
party =("pizza", "burger", "pasta","pizza", "burger")
# Out:
# 2

# %%
party.index("burger")
# Out:
# 1

# %%
party.count("pizza")
# Out:
# 2

# %%
party.index("burger")
# Out:
# 1

# %%
print("I like to eat:",fruits[0])
# Out:
# I like to eat: apple
