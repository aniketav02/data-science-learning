# %%
student ={"Name":"Rock"}

# %%
student
# Out:
# {'Name': 'Rock'}

# %%
student ={"Name":"Rock","Name":"Ram"}

# %%
student
# Out:
# {'Name': 'Ram'}

# %%
#create a dict
student={"Name":"Rock","City":"Kop","Class":10}

# %%
student
# Out:
# {'Name': 'Rock', 'City': 'Kop', 'Class': 10}

# %%
student.keys()
# Out:
# dict_keys(['Name', 'City', 'Class'])

# %%
student.values()
# Out:
# dict_values(['Rock', 'Kop', 10])

# %%
student.items()
# Out:
# dict_items([('Name', 'Rock'), ('City', 'Kop'), ('Class', 10)])

# %%
student_profile={"Name":"Aniket",
                 "Class":10,
                 "marks":[100,90,89,90,89],
                 "city":"Kolhapur",
                 "Sports":"Cricket"}

# %%
student_profile.keys()
# Out:
# dict_keys(['Name', 'Class', 'marks', 'city', 'Sports'])

# %%
student_profile.values()
# Out:
# dict_values(['Aniket', 10, [100, 90, 89, 90, 89], 'Kolhapur', 'Cricket'])

# %%
student_profile.items()
# Out:
# dict_items([('Name', 'Aniket'), ('Class', 10), ('marks', [100, 90, 89, 90, 89]), ('city', 'Kolhapur'), ('Sports', 'Cricket')])

# %%
for k,v in student_profile.items():
    print(k,"->",v)
# Out:
# Name -> Aniket
# Class -> 10
# marks -> [100, 90, 89, 90, 89]
# city -> Kolhapur
# Sports -> Cricket

# %%
student_profile["marks"]
# Out:
# [100, 90, 89, 90, 89]

# %%
student_profile.get("ID")

# %%
student_profile.get("Gender")

# %%
for k,v in student_profile.items():
    print(k,v)
# Out:
# Name Aniket
# Class 10
# marks [100, 90, 89, 90, 89]
# city Kolhapur
# Sports Cricket

# %%
student_profile.get("id","Key not present")
# Out:
# 'Key not present'

# %%
student_profile.get("Name","Key not present")
# Out:
# 'Aniket'

# %%
student_profile.get("id","001")
# Out:
# '001'

# %%
student_profile.update({"id": 1})

# %%
student_profile
# Out:
# {'Name': 'Aniket',
#  'Class': 10,
#  'marks': [100, 90, 89, 90, 89],
#  'city': 'Kolhapur',
#  'Sports': 'Cricket',
#  'id': 1}

# %%
student_profile.update({"Gender":"Male","Division":"A"})

# %%
student_profile
# Out:
# {'Name': 'Aniket',
#  'Class': 10,
#  'marks': [100, 90, 89, 90, 89],
#  'city': 'Kolhapur',
#  'Sports': 'Cricket',
#  'id': 1,
#  'Gender': 'Male',
#  'Division': 'A'}

# %%
for k,v in student_profile.items():
    print(k,":",v)
# Out:
# Name : Aniket
# Class : 10
# marks : [100, 90, 89, 90, 89]
# city : Kolhapur
# Sports : Cricket
# id : 1
# Gender : Male
# Division : A

# %%
student_profile.update({"marks":[90,90,9,90,90,90,9]})

# %%
for k,v in student_profile.items():
    print(k,":",v)
# Out:
# Name : Aniket
# Class : 10
# marks : [90, 90, 9, 90, 90, 90, 9]
# city : Kolhapur
# Sports : Cricket
# id : 1
# Gender : Male
# Division : A

# %%
student_profile.pop("Division")
# Out:
# 'A'

# %%
for k,v in student_profile.items():
    print(k,":",v)
# Out:
# Name : Aniket
# Class : 10
# marks : [90, 90, 9, 90, 90, 90, 9]
# city : Kolhapur
# Sports : Cricket
# id : 1
# Gender : Male

# %%
student_profile.clear()

# %%
student_profile.items()
# Out:
# dict_items([])

# %%
a={"food":"oats","Drink":"Coffee"}

# %%
b=a.copy()
b
# Out:
# {'food': 'oats', 'Drink': 'Coffee'}

# %%
for k,v in b.items():
    print(k,":",v)
# Out:
# food : oats
# Drink : Coffee

# %%
marks= {
    "Pradip":45,
    "gaurav":78,
    "Sneha":90,
    "Ravi":32,
    "Meena":55
}

# %%
for k , v in marks.items():
    if v >=50:
        print(k,":",v)
# Out:
# gaurav : 78
# Sneha : 90
# Meena : 55
