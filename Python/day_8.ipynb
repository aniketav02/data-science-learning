# %%
cart =["spinach","tomato","avacado","drinks"]

# %%
for i in cart:
    if i == 'avacado':
        print("We found:",i )
        break
    print(i)
# Out:
# spinach
# tomato
# We found: avacado

# %%
marks = [45,65,43,54,33,100]

# %%
for i in marks:
    if i <=35:
        print("Failed: ",i)
    else:
        print("Passed: ",i)
# Out:
# Passed:  45
# Passed:  65
# Passed:  43
# Passed:  54
# Failed:  33
# Passed:  100

# %%
apps =["blinkit","zepto","zomato","swiggy","fkipcart"]

# %%
for i in apps:
    print("Chechking app ",i)
    if i == "zomato":
        print(i,"App Found")
        break
# Out:
# Chechking app  blinkit
# Chechking app  zepto
# Chechking app  zomato
# zomato App Found

# %%
snacks =["chips","taco","burger","ban maska","oats","softy"]

# %%
for i in snacks:
    if i== "oats":
        print("skip it plz",i)
        continue
    print("Yummy eating",i)
# Out:
# Yummy eating chips
# Yummy eating taco
# Yummy eating burger
# Yummy eating ban maska
# skip it plz oats
# Yummy eating softy

# %%
marks = [78,65,85,67,56,100,87]

# %%
for i in marks:
    if i < 90:
        print(i,"You are getting books.")
    else:
        print(i,"You are getting medal")
# Out:
# 78 You are getting books.
# 65 You are getting books.
# 85 You are getting books.
# 67 You are getting books.
# 56 You are getting books.
# 100 You are getting medal
# 87 You are getting books.

# %%
nums = [1,2,3,4,5,6]

for i in nums:
    if i ==3:
        pass
    else:
        print(i)
# Out:
# 1
# 2
# 4
# 5
# 6

# %%
marks = [85,30,75,40,25,90]

# %%
for i in marks:
    if i<40:
        pass
    else:
        print("U pass exam",i)
# Out:
# U pass exam 85
# U pass exam 75
# U pass exam 40
# U pass exam 90

# %%
search= input()
