# %%
cart ={"rice"}

# %%
cart.add("water")
print(cart)
# Out:
# {'water', 'rice'}

# %%
cart.add('')

# %%
cart.clear()

# %%
cart
# Out:
# set()

# %%
record =["rahul","karan","Samix","Rohit"]
print(record)
# Out:
# ['rahul', 'karan', 'Samix', 'Rohit']

# %%
present = set()

# %%
for i in record:
    print("Present")
# Out:
# Present
# Present
# Present
# Present

# %%
fruits ={"apple","mango"}

# %%
fruits.update(['oranges','kiwi','oranges'])

# %%
fruits
# Out:
# {'apple', 'kiwi', 'mango', 'oranges'}

# %%
fruits.update(["Banana"])

# %%
fruits
# Out:
# {'Banana', 'apple', 'kiwi', 'mango', 'oranges'}

# %%
#add 
#update
#remove : the item should present, if no: the errror
#discard : no matter item is present or not :if present it remove

# %%
print(fruits)
# Out:
# {'mango', 'Banana', 'apple', 'kiwi', 'oranges'}

# %%
fruits.remove("apple")

# %%
fruits
# Out:
# {'Banana', 'kiwi', 'mango', 'oranges'}

# %%
product= {"Board","Screen","Code"}

# %%
#product.remove("Laptop")
product.discard("Laptop")

# %%
# .add() = addiing the item
# .update() = adding the multiple items in one go
# .remove() = removing the items
# .discard() = removing single element
# .pop() = randomly remove item
# .clear() =
# .copy() =

# %%
lottery = {"aniket","saurabh","samix","rohit"}

# %%
lottery.pop()
# Out:
# 'saurabh'

# %%
lottery
# Out:
# {'aniket', 'rohit', 'samix'}

# %%
lottery.pop()
# Out:
# 'rohit'

# %%
lottery
# Out:
# {'aniket', 'samix'}

# %%
lottery.clear()

# %%
lottery
# Out:
# set()

# %%
a = {"mango","kiwi"}
b = a.copy()

# %%
b
# Out:
# {'kiwi', 'mango'}

# %%
new_set= a.copy()
print(new_set)
# Out:
# {'kiwi', 'mango'}

# %%
print(a)
print(new_set)
# Out:
# {'kiwi', 'mango'}
# {'kiwi', 'mango'}

# %%
# print set elements
fruits = {"apple" , "banana" , "cherry"} # use for loop to pring each elements

# %%
for fruit in fruits:
    print(fruit)
# Out:
# mango
# Banana
# kiwi
# oranges

# %%
# print squres from set
nums = {2,4,6,8}

# %%
for n in nums:
    print(n*2)
# Out:
# 16
# 4
# 8
# 12

# %%
# check membership
members = {"amit" , "sneha" , "rahul"} # use a for loop to check if "sneha" is present

# %%
for i in members:
    if i =="sneha":
        print(i,"is present")
# Out:
# sneha is present

# %%
#count elements
ele={1,2,3,4,5,6} # use for loop

# %%
print(ele)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
count = 0
for i in ele:
    count +=1
print(count)
# Out:
# 6

# %%
count
# Out:
# 6

# %%
# use for loop to find th percentage
marks =[86,75,43,54,56,55]

# %%
total = 0
for i in marks:
    total += i
percentage = total / len(marks)

print(percentage)
# Out:
# 61.5

# %%
nums= [33,4,5,666,77,55]

# %%
# filter even numbers
nums = {1,2,3,4,5,6,7}

# %%
for i in nums:
    if i%2 == 0:
        print(i)
# Out:
# 2
# 4
# 6

# %%
# find the max number without using max()
nums = [56,67,78,456,43,56,76,8,56]

# %%
larg = nums[0]

for i in nums:
    if i>larg:
        larg=i
print(larg)
# Out:
# 456
