# %%
a = ["remote","Screen", "Board"]
print(a)
# Out:
# ['remote', 'Screen', 'Board']

# %%
b =["stand","bench","button"]
print(b)
# Out:
# ['stand', 'bench', 'button']

# %%
b[2]="bottle"
print(b)
# Out:
# ['stand', 'bench', 'bottle']

# %%
a = [[1,2,3],[4,5,6]]
print(a)
# Out:
# [[1, 2, 3], [4, 5, 6]]

# %%
color = ["red","green","blue"]
print(color)
# Out:
# ['red', 'green', 'blue']

# %%
bus =["Volvo","Tata","Ashok Leyland"]
print(bus)
# Out:
# ['Volvo', 'Tata', 'Ashok Leyland']

# %%
num = [1,2,3,4,5]
len(num)
# Out:
# 5

# %%
a = ["remote","Screen", "Board"]
len(a)
# Out:
# 3

# %% [markdown]
# # .append() method is used to add an element at the end of the list.

# %%
trip = ["Delhi","Mumbai","Kolkata"]
print(trip)
# Out:
# ['Delhi', 'Mumbai', 'Kolkata']

# %%
trip.append("Chennai")

# %%
print(trip)
# Out:
# ['Delhi', 'Mumbai', 'Kolkata', 'Chennai']

# %%
a =[]
print(a)
# Out:
# []

# %%
a.append("remote")

# %%
print(a)
# Out:
# ['remote']

# %%
a = ["remote","Screen", "Board"]
b =["stand","bench","button"]
a.extend(b)

# %%
print(a)
# Out:
# ['remote', 'Screen', 'Board', 'stand', 'bench', 'button']

# %%
color = ["red","green","blue"]
color2 =["yellow","orange"]
color2.extend(color)
print(color2)
# Out:
# ['yellow', 'orange', 'red', 'green', 'blue']

# %%
a.extend(color2)
print(a)
# Out:
# ['remote', 'Screen', 'Board', 'stand', 'bench', 'button', 'yellow', 'orange', 'red', 'green', 'blue']

# %%
# method: .insert()
name = ["Aniket","Rohit","Saurabh"]

# %%
name.insert(1,"Sanmesh")

# %%
print(name)
# Out:
# ['Aniket', 'Sanmesh', 'Rohit', 'Saurabh']

# %%
name.insert(3,"Pranav")

# %%
name
# Out:
# ['Aniket', 'Sanmesh', 'Rohit', 'Pranav', 'Saurabh']

# %% [markdown]
# # todays

# %%
a = ["rice"]
print(a)
# Out:
# ['rice']

# %%
b = ["cookies",'bread','chocolate']
a.extend(b)

# %%
a
# Out:
# ['rice', 'cookies', 'bread', 'chocolate']

# %%
a.remove("cookies")
print(a)
# Out:
# ['rice', 'bread', 'chocolate']

# %%
a.remove("rice")

# %%
a
# Out:
# ['bread', 'chocolate']

# %%
# append : add element at the end of the list.
# extend : add the another list
# insert : add the element at the given index.
# remove : remove the element from the list.

# %%
cart =["tshirt","jeans","shoes"]
cart
# Out:
# ['tshirt', 'jeans', 'shoes']

# %%
cart.pop()
# Out:
# 'shoes'

# %%
len(cart)
# Out:
# 2

# %%
cart.pop(1)
cart
# Out:
# ['tshirt']

# %%
len(cart)
# Out:
# 1

# %%
cart
# Out:
# ['tshirt']

# %%
print(trip)
# Out:
# ['Delhi', 'Mumbai', 'Kolkata', 'Chennai']

# %%
trip.clear()

# %%
trip
# Out:
# []

# %%
a = [10,20,30,40,50]
a
# Out:
# [10, 20, 30, 40, 50]

# %%
a.index(30)
# Out:
# 2

# %%
# append : adding element in last
# extend : adding another list
# insert : adding element at a specific index
# remove : removing a specific element
# pop : removing element at a specific index
# clear : removing all elements from the list
# index : find the index of item 
# count : count the item frequency
# sort : sort the list in ascending order

# %%
a = ["apple","banana","cherry","apple","banana","apple"]

# %%
len(a)
# Out:
# 6

# %%
a = [2,3,4,56,7,8,96,3,2,1]
a.sort(reverse = True)
a
# Out:
# [96, 56, 8, 7, 4, 3, 3, 2, 2, 1]

# %%
a.reverse()
a
# Out:
# ['apple', 'banana', 'apple', 'cherry', 'banana', 'apple']

# %%
# append : adding element in last
# extend : adding another list
# insert : adding element at a specific index
# remove : removing a specific element
# pop : removing element at a specific index[last element /index position]
# clear : removing all elements from the list
# index : find the index of item 
# count : count the item frequency
# sort : sort the list in ascending order
# reverse : reverse the list : reverse = True
